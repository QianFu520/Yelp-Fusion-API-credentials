# %%
import json
with open('/Users/qfu88/.secret/yelp_api.json') as f: 
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 11800

# %%
import pandas as pd
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/HVjttL...
# 1            Juliana's  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4500
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2523
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
#
#     display_phone     distance
# 0  (212) 966-4100  1961.877142
# 1  (718) 596-6700   308.569844

# %%
## how many businesses in our results
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                    alias         name  \
# 0  16ZnHpuaaBt92XWeJHCC5A    olio-e-più-new-york-7   Olio e Più
# 1  4h4Tuuc56YPO6lWfZ1bdSQ  joes-pizza-new-york-152  Joe's Pizza
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/Nn4I1S...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/yo5oXK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          3578
# 1  https://www.yelp.com/biz/joes-pizza-new-york-1...           377
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.733798036104304, 'longitude': ...  [delivery, pickup]
# 1  {'latitude': 40.7101297729083, 'longitude': -7...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '3 Greenwich Ave', 'address2': No...  +12122436546
# 1     $  {'address1': '124 Fulton St', 'address2': '', ...  +12122670860
#
#     display_phone     distance
# 0  (212) 243-6546  3186.380498
# 1  (212) 267-0860  1245.942863

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 2  tpcCX_SHaNXqAzXOzbluJQ             fini-pizza-brooklyn
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/HVjttL...
# 1            Juliana's  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...
# 2           Fini Pizza  https://s3-media3.fl.yelpcdn.com/bphoto/UEW7bE...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4500
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2523
# 2      False  https://www.yelp.com/biz/fini-pizza-brooklyn?a...            12
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 2     {'latitude': 40.71348, 'longitude': -73.96182}                  []
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 2   NaN  {'address1': '305 Bedford Ave', 'address2': ''...
#
#     display_phone     distance
# 0  (212) 966-4100  1961.877142
# 1  (718) 596-6700   308.569844
# 2                  2882.711683
#                         id                              alias  \
# 37  -CCfu19Uuy_kD2t4ZwsQfA    village-square-pizza-new-york-3
# 38  ynQ8NJB7SEAIkuUxopHPvA                  ignazios-brooklyn
# 39  qoBcWhGwlcUsKIQ2nB22vA  lombardos-of-bay-ridge-brooklyn-2
#
#                        name  \
# 37     Village Square Pizza
# 38                Ignazio's
# 39  Lombardo's of Bay Ridge
#
#                                             image_url  is_closed  \
# 37  https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5...      False
# 38  https://s3-media4.fl.yelpcdn.com/bphoto/8X6uFK...      False
# 39  https://s3-media2.fl.yelpcdn.com/bphoto/dApR-o...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/village-square-pizza-...           241
# 38  https://www.yelp.com/biz/ignazios-brooklyn?adj...           587
# 39  https://www.yelp.com/biz/lombardos-of-bay-ridg...           183
#
#                                            categories  rating  \
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 38             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 39  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
#
#                                           coordinates        transactions  \
# 37     {'latitude': 40.72748, 'longitude': -73.98268}  [pickup, delivery]
# 38   {'latitude': 40.703137, 'longitude': -73.993608}  [pickup, delivery]
# 39  {'latitude': 40.634741, 'longitude': -74.0284259}  [pickup, delivery]
#
#    price                                           location         phone  \
# 37     $  {'address1': '147 Ave A', 'address2': None, 'a...  +19176757709
# 38    $$  {'address1': '4 Water St', 'address2': '', 'ad...  +17185222100
# 39    $$  {'address1': '279 71st St', 'address2': None, ...  +17182387100
#
#      display_phone     distance
# 37  (917) 675-7709  2640.263835
# 38  (718) 522-2100   263.042502
# 39  (718) 238-7100  8367.095256
